# %%
def sigmoid(x):
  import math 
  return 1/(1+math.exp(-x))
sigmoid(18)
# Out:
# 0.9999999847700205

# %%
import numpy as np

def sigmoid_numpy(X):
  return 1/(1+np.exp(-X))

# %%
#Function for gradient descent which is used for finding weights and biases in a neural network

def gradient_descent(age , affordability , y_true , epochs):
  #Let w1 = w2 = 1 for start and learning rate as 0.5 and bias value as 0
  w1 = w2 = 1 
  bias = 0 
  rate = 0.5
  n = len(age)


  for i in range(epochs):
    weighted_sum = w1*age + w2*affordability + bias
    y_predicted = sigmoid_numpy(weighted_sum)
