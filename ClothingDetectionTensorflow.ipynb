# %%
import tensorflow as tf 
data = tf.keras.datasets.fashion_mnist
(training_images , training_labels) , (test_images , test_labels) = data.load_data()

training_images = training_images/255.0
test_images = test_images/255.0 
#In the first layer only we have to specify our input data shape
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape = (28,28)) , tf.keras.layers.Dense(128 , activation = tf.nn.relu ) , tf.keras.layers.Dense(10 , activation = tf.nn.softmax)])
model.compile(optimizer = 'adam' , loss='sparse_categorical_crossentropy' , metrics=['accuracy'])
model.fit(training_images , training_labels , epochs = 5)
model.evaluate(test_images , test_labels)
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5005 - accuracy: 0.8246
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3759 - accuracy: 0.8647
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3394 - accuracy: 0.8758
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3119 - accuracy: 0.8855
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 1ms/step - loss: 0.3443 - accuracy: 0.8759
# [0.34426331520080566, 0.8758999705314636]

# %%
classifications = model.predict(test_images)
print(classifications[0])
print(test_labels[0])
# Out:
# [9.3144644e-07 8.1293230e-08 4.2303742e-07 4.5035641e-08 2.0752817e-07
#  1.0431979e-03 1.4575228e-06 2.5522225e-02 3.9115666e-06 9.7342753e-01]
# 9

# %% [markdown]
# **We Dont know when our model will acheive 95% accuracy so to determine the epochs we will use a callbackFunction**

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self , epoch , logs = {}):
    if(logs.get('accuracy')>0.99):
      print("\n Reached 95% accuracy so cancelling training")
      self.model.stop_training = True 

callbacks = myCallback() 
model.fit(training_images , training_labels , epochs = 50 , callbacks = [callbacks])
model.evaluate(test_images , test_labels)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2801 - accuracy: 0.8963
# Epoch 2/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2668 - accuracy: 0.9016
# Epoch 3/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2565 - accuracy: 0.9048
# Epoch 4/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2454 - accuracy: 0.9084
# Epoch 5/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2376 - accuracy: 0.9122
# Epoch 6/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2296 - accuracy: 0.9144
# Epoch 7/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2226 - accuracy: 0.9175
# Epoch 8/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2168 - accuracy: 0.9190
# Epoch 9/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2098 - accuracy: 0.9218
# Epoch 10/50
# ...

# %%
#ADDING CNN (Convolutional Neural Network) to our model 
import tensorflow as tf 
data = tf.keras.datasets.fashion_mnist
(training_images , training_labels) , (test_images , test_labels) = data.load_data()

training_images = training_images.reshape(60000, 28, 28, 1)
training_images = training_images/255.0 
test_images = test_images.reshape(10000, 28, 28, 1)
test_images = test_images/255.0
#In the first layer only we have to specify our input data shape
model = tf.keras.models.Sequential([
  #In this case, we want the layer to learn 64 filters or 64 convolutions. 
  # 3,3 is the size of the filter 
  tf.keras.layers.Conv2D(64 , (3,3) , activation='relu' , input_shape = (28,28,1)) , 
  tf.keras.layers.MaxPooling2D(2,2) , 
  tf.keras.layers.Conv2D(64 , (3,3) , activation='relu') , 
  tf.keras.layers.MaxPooling2D(2,2) , 
  tf.keras.layers.Flatten()
 , tf.keras.layers.Dense(128 , activation = tf.nn.relu ) ,
  tf.keras.layers.Dense(10 , activation = tf.nn.softmax)])


model.compile(optimizer = 'adam' , loss='sparse_categorical_crossentropy' , metrics=['accuracy'])
model.fit(training_images , training_labels , epochs = 50)
model.evaluate(test_images , test_labels)
classifications = model.predict(test_images)
print(classifications[0])
print(test_labels[0])
model.summary
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
#  169/1875 [=>............................] - ETA: 1:41 - loss: 0.8474 - accuracy: 0.6951
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-47e425ae4016> in <module>()
#      22
#      23 model.compile(optimizer = 'adam' , loss='sparse_categorical_crossentropy' , metrics=['accuracy'])
# ---> 24 model.fit(training_images , training_labels , epochs = 50)
#      25 model.evaluate(test_images , test_labels)
#      26 classifications = model.predict(test_images)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
# ...
